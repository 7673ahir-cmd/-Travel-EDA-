# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  


import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\Pc\OneDrive\Documents\my_csv\Travel.csv")

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   str
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   str
#  7   Gender                    4888 non-null   str
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   str
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   str
#  13  NumberOfTrips             4748 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %%
df.Gender.unique()
# Out:
# <ArrowStringArray>
# ['Female', 'Male', 'Fe Male']
# Length: 3, dtype: str

# %%
df.replace("Fe Male","Female", inplace=True)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.Gender.unique()
# Out:
# <ArrowStringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# DurationOfPitch             251
# MonthlyIncome               233
# Age                         226
# NumberOfTrips               140
# NumberOfChildrenVisiting     66
# NumberOfFollowups            45
# PreferredPropertyStar        26
# TypeofContact                25
# Designation                   0
# OwnCar                        0
# PitchSatisfactionScore        0
# Passport                      0
# CustomerID                    0
# MaritalStatus                 0
# ProdTaken                     0
# NumberOfPersonVisiting        0
# Gender                        0
# Occupation                    0
# CityTier                      0
# ProductPitched                0
# dtype: int64

# %%
df.isnull().sum()/len(df.index)*100
# Out:
# CustomerID                  0.000000
# ProdTaken                   0.000000
# Age                         4.623568
# TypeofContact               0.511457
# CityTier                    0.000000
# DurationOfPitch             5.135025
# Occupation                  0.000000
# Gender                      0.000000
# NumberOfPersonVisiting      0.000000
# NumberOfFollowups           0.920622
# ProductPitched              0.000000
# PreferredPropertyStar       0.531915
# MaritalStatus               0.000000
# NumberOfTrips               2.864157
# Passport                    0.000000
# PitchSatisfactionScore      0.000000
# OwnCar                      0.000000
# NumberOfChildrenVisiting    1.350245
# Designation                 0.000000
# MonthlyIncome               4.766776
# dtype: float64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()/len(df.index)
# Out:
# CustomerID                  0.0
# ProdTaken                   0.0
# Age                         0.0
# TypeofContact               0.0
# CityTier                    0.0
# DurationOfPitch             0.0
# Occupation                  0.0
# Gender                      0.0
# NumberOfPersonVisiting      0.0
# NumberOfFollowups           0.0
# ProductPitched              0.0
# PreferredPropertyStar       0.0
# MaritalStatus               0.0
# NumberOfTrips               0.0
# Passport                    0.0
# PitchSatisfactionScore      0.0
# OwnCar                      0.0
# NumberOfChildrenVisiting    0.0
# Designation                 0.0
# MonthlyIncome               0.0
# dtype: float64

# %%
df.shape
# Out:
# (4128, 20)

# %%
cats=['ProdTaken','CityTier','PreferredPropertyStar','Passport','OwnCar','PitchSatisfactionScore','TypeofContact','Occupation','Gender','ProductPitched','MaritalStatus','Designation']

# %%
nums=['CustomerID','Age','DurationOfPitch','NumberOfPersonVisiting','NumberOfFollowups','NumberOfTrips','NumberOfChildrenVisiting','MonthlyIncome']

# %%
cats
# Out:
# ['ProdTaken',
#  'CityTier',
#  'PreferredPropertyStar ',
#  'Passport ',
#  'OwnCar',
#  'PitchSatisfactionScore ',
#  'TypeofContact',
#  'Occupation',
#  'Gender ',
#  'ProductPitched ',
#  'MaritalStatus',
#  'Designation']

# %%
nums
# Out:
# ['CustomerID ',
#  'Age',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
#Univariate analysis for categorical columns
for cat_column in cats:
    plt.figure(figsize=(10,5))
    sns.countplot(x = cat_column, data =df, palette = 'viridis')
    plt.title(f'Univariate analysis - {cat_column}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       2 for cat_column in cats:
#       3     plt.figure(figsize=(10,5))
# ----> 4     sns.countplot(x = cat_column, data =df, palette = 'viridis')
#       5     plt.title(f'Univariate analysis - {cat_column}')
#       6     plt.show()
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
# ...

# %%
for num_column in nums:
    plt.figure(figsize=(10,5))
    sns.histplot(df[num_column], kde =True, color='skyblue')
    plt.title(f'Univariate analysis - {num_column}')
    plt.show()

# %%
plt.hist(df['Age'].dropna(), bins=30,color='skyblue',edgecolor='black')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel('Frequency')
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %%
df['TypeofContact']
# Out:
# 0          Self Enquiry
# 1       Company Invited
# 2          Self Enquiry
# 3       Company Invited
# 5       Company Invited
#              ...
# 4883       Self Enquiry
# 4884    Company Invited
# 4885       Self Enquiry
# 4886       Self Enquiry
# 4887       Self Enquiry
# Name: TypeofContact, Length: 4128, dtype: str

# %%
sns.countplot(x = 'TypeofContact', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='TypeofContact', ylabel='count'>

# %%
for i in df[cats].columns:
    x=df[i].unique()
    print(f"{i} : {x}")
    print()
# Out:
# ProdTaken : [1 0]
#
# CityTier : [3 1 2]
#
# PreferredPropertyStar : [3. 4. 5.]
#
# Passport : [1 0]
#
# OwnCar : [1 0]
#
# PitchSatisfactionScore : [2 3 5 4 1]
#
# TypeofContact : <ArrowStringArray>
# ['Self Enquiry', 'Company Invited']
# Length: 2, dtype: str
#
# Occupation : <ArrowStringArray>
# ['Salaried', 'Free Lancer', 'Small Business', 'Large Business']
# Length: 4, dtype: str
#
# Gender : <ArrowStringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# ProductPitched : <ArrowStringArray>
# ['Deluxe', 'Basic', 'Standard', 'Super Deluxe', 'King']
# Length: 5, dtype: str
#
# MaritalStatus : <ArrowStringArray>
# ['Single', 'Divorced', 'Married', 'Unmarried']
# Length: 4, dtype: str
#
# Designation : <ArrowStringArray>
# ['Manager', 'Executive', 'Senior Manager', 'AVP', 'VP']
# Length: 5, dtype: str

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %%
sns.scatterplot(x= 'Age', y='DurationOfPitch', data = df, hue = 'ProdTaken', palette = 'viridis')
# Out:
# <Axes: xlabel='Age', ylabel='DurationOfPitch'>

# %%
cross_tab=pd.crosstab(df['MaritalStatus'], df['ProdTaken'], normalize='index')*100

cross_tab.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %%
sns.barplot(x='ProductPitched',y='PitchSatisfactionScore',data=df, palette='viridis')
# Out:
# <Axes: xlabel='ProductPitched', ylabel='PitchSatisfactionScore'>

# %%
sns.lineplot(x= 'NumberOfFollowups', y = 'PitchSatisfactionScore',data=df, marker='o',color ='purple')
# Out:
# <Axes: xlabel='NumberOfFollowups', ylabel='PitchSatisfactionScore'>

# %%
sns.violinplot(x='ProdTaken', y='Age', data=df , palette='viridis')
# Out:
# <Axes: xlabel='ProdTaken', ylabel='Age'>

# %%
sns.swarmplot(x = 'Gender', y='Age', data=df, hue= 'ProdTaken',palette='viridis')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Age'],df['MonthlyIncome'],df['DurationOfPitch'], c=df['ProdTaken'], cmap='viridis')
ax.set_xlabel('Age')
ax.set_ylabel('Monthly Income')
ax.set_zlabel('Duration of Pitch')
ax.set_title('3D Scatter Plot of Age, Monthly Income, and Duration of Pitch')
plt.show()

# %%
numeric_cols = df.select_dtypes(include='number')
sns.heatmap(numeric_cols.corr(), cmap='viridis', annot=True, fmt = '.1f')
# Out:
# <Axes: >

# %%
df.drop('CustomerID', inplace=True, axis =1)

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='str')

# %%
df.shape
# Out:
# (4128, 19)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('ProdTaken', axis =1)
y=df['ProdTaken']

# %%
x
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     41.0     Self Enquiry         3              6.0        Salaried
# 1     49.0  Company Invited         1             14.0        Salaried
# 2     37.0     Self Enquiry         1              8.0     Free Lancer
# 3     33.0  Company Invited         1              9.0        Salaried
# 5     32.0  Company Invited         1              8.0        Salaried
# ...    ...              ...       ...              ...             ...
# 4883  49.0     Self Enquiry         3              9.0  Small Business
# 4884  28.0  Company Invited         1             31.0        Salaried
# 4885  52.0     Self Enquiry         3             17.0        Salaried
# 4886  19.0     Self Enquiry         3             16.0  Small Business
# 4887  36.0     Self Enquiry         1             14.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 5       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4128, dtype: int64

# %%
train_test_split(x,y, test_size=0.2,random_state=1)
# Out:
# [       Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
#  3444  53.0     Self Enquiry         1             15.0        Salaried
#  4355  43.0  Company Invited         1             12.0        Salaried
#  1374  58.0     Self Enquiry         3             27.0        Salaried
#  4432  39.0     Self Enquiry         3             14.0  Small Business
#  603   45.0     Self Enquiry         1              8.0        Salaried
#  ...    ...              ...       ...              ...             ...
#  3535  34.0     Self Enquiry         1             32.0        Salaried
#  3386  37.0     Self Enquiry         1             17.0  Large Business
#  1160  45.0     Self Enquiry         1              8.0        Salaried
#  4717  35.0  Company Invited         1             10.0        Salaried
#  289   28.0     Self Enquiry         1             14.0        Salaried
#
#        Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# ...
